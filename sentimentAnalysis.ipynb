# %% [markdown]
# # Twitter Sentiment Analysis
#
# This is an attempt to create a model that can determine the sentiment behind a Tweet posted on a specific topic.
# In this notebook, I will be using a dataset that contains a load of Tweets taken from the Twitter API.
# The dataset is available [here](https://www.kaggle.com/kazanova/sentiment140).
#
# Citation for the data: Go, A., Bhayani, R. and Huang, L., 2009. Twitter sentiment classification using distant supervision. CS224N Project Report, Stanford, 1(2009), p.12.
#
# The dataset being used is the sentiment140 dataset. It contains 1,600,000 tweets extracted using the Twitter API. The tweets have been annotated (0 = Negative, 4 = Positive) and they can be used to detect sentiment.
#
# [The training data isn't perfectly categorised as it has been created by tagging the text according to the emoji present. So, any model built using this dataset may have lower than expected accuracy, since the dataset isn't perfectly categorised.]
#
# It contains the following 6 fields:
#
#     - sentiment: the polarity of the tweet (0 = negative, 4 = positive)
#     - ids: The id of the tweet (2087)
#     - date: the date of the tweet (Sat May 16 23:58:44 UTC 2009)
#     - flag: The query (lyx). If there is no query, then this value is NO_QUERY.
#     - user: the user that tweeted (robotickilldozr)
#     - text: the text of the tweet (Lyx is cool)

# %% [markdown]
# ## Importing Necessary Packages

# %%
# Uitilities
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading the dataset

# %%
colNames = ['Sentiment', 'id', 'date', 'flag', 'user', 'text']

df = pd.read_csv('data/training.1600000.processed.noemoticon.csv', encoding = "ISO-8859-1", names = colNames)
df.head()
# Out:
#    Sentiment          id                          date      flag  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# Since Only *Sentiment* and *text* is required for sentiment analysis, other columns will be dropped.

# %%
df = df[['Sentiment', 'text']]
df.head()
# Out:
#    Sentiment                                               text
# 0          0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          0  is upset that he can't update his Facebook by ...
# 2          0  @Kenichan I dived many times for the ball. Man...
# 3          0    my whole body feels itchy and like its on fire
# 4          0  @nationwideclass no, it's not behaving at all....

# %%
df.loc[df['Sentiment'] == 0]
# Out:
#         Sentiment                                               text
# 0               0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1               0  is upset that he can't update his Facebook by ...
# 2               0  @Kenichan I dived many times for the ball. Man...
# 3               0    my whole body feels itchy and like its on fire
# 4               0  @nationwideclass no, it's not behaving at all....
# 5               0                      @Kwesidei not the whole crew
# 6               0                                        Need a hug
# 7               0  @LOLTrish hey  long time no see! Yes.. Rains a...
# 8               0               @Tatiana_K nope they didn't have it
# 9               0                          @twittera que me muera ?
# 10              0        spring break in plain city... it's snowing
# 11              0                         I just re-pierced my ears
# 12              0  @caregiving I couldn't bear to watch it.  And ...
# 13              0  @octolinz16 It it counts, idk why I did either...
# 14              0  @smarrison i would've been the first, but i di...
# 15              0  @iamjazzyfizzle I wish I got to watch it with ...
# 16              0  Hollis' death scene will hurt me severely to w...
# 17              0                               about to file taxes
# 18              0  @LettyA ahh ive always wanted to see rent  lov...
# 19              0  @FakerPattyPattz Oh dear. Were you drinking ou...
# 20              0  @alydesigns i was out most of the day so didn'...
# 21              0  one of my friend called me, and asked to meet ...
# 22              0   @angry_barista I baked you a cake but I ated it
# 23              0             this week is not going as i had hoped
# 24              0                         blagh class at 8 tomorrow
# 25              0     I hate when I have to call and wake people up
# 26              0  Just going to cry myself to sleep after watchi...
# 27              0                             im sad now  Miss.Lilly
# 28              0  ooooh.... LOL  that leslie.... and ok I won't ...
# 29              0  Meh... Almost Lover is the exception... this t...
# ...           ...                                                ...
# 799970          0  @mcdeezer. Aww shoot. Wonder if she tied the k...
# 799971          0    Ugh I really don't want to go to school today.
# 799972          0  @teemwilliams tell her to pray for me too!! i ...
# 799973          0  got down to $0 in checking over a week ago. Lu...
# 799974          0        RIP Farrah, I hope you have some peace now
# 799975          0                                  RIP Jill Monroe.
# 799976          0                            doesnt know what to do
# 799977          0                    said goodbye to sam and rachel
# 799978          0  .good for miley..i'm still awake in te MIDNIGH...
# 799979          0  Big lump in my throat from reading about Farra...
# 799980          0  @nitchxo I get pressure behind my left eye som...
# 799981          0                      i have nothing to do now  ugh
# 799982          0                         I'm so sad I'm leaving FL
# 799983          0  @shelbytyszka hmm, that doesn't sound anywhere...
# 799984          0  @ehasselbeck wtching the show 10:28am here...W...
# 799985          0              ugh, all my pics r too bog 4 twitter
# 799986          0  I feel so dumb because my host  so smart at al...
# 799987          0  R.I.P. Farrah God bless My prayers and love go...
# 799988          0               Farrah Fawcett passed away...so sad
# 799989          0  Just payed my WAY OVERDUE zta dues. Goodbye $3...
# 799990          0  and I think it has a mind of its own,like it a...
# 799991          0  @iaintnohomo  Banana will be playing later. BU...
# 799992          0                   @koolgirl37 read my tweet below
# 799993          0        My life  http://mattf.ca/2009/06/24/yay-me/
# 799994          0  Tried to get the mutant Fawkes to follow me bu...
# 799995          0  Sick  Spending my day laying in bed listening ...
# 799996          0                                    Gmail is down?
# 799997          0                      rest in peace Farrah! So sad
# 799998          0  @Eric_Urbane Sounds like a rival is flagging y...
# 799999          0  has to resit exams over summer...  wishes he w...
#
# [800000 rows x 2 columns]
